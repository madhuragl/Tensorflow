# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series((["BMW", "Toyota", "Honda"]))

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
#series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# Dataftame = 2 dimensional
car_data = pd.DataFrame({"Car make": series, "Colour" : colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
#import data
car_sales = pd.read_csv("/content/drive/MyDrive/Datas/car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
export_car_sales = pd.read_csv("/content/exported-car-sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
#attribuute doesnt have ()
car_sales.dtypes
#while fnctions have () e.g. 
#ca_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe() #give statistical information abot numeric coluumns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
#here price is object hence not listed

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00 $5,000.00 $7,000.00 $22,000.00 $3,50...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)  #give numebr of rows
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## viewing and seleting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc and .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index=[0,3,9,8,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]   #loc refers to index number
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                     BMW
# Colour                 Black
# Odometer (KM)          11179
# Doors                      5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#.iloc refers to carposition
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                     BMW
# Colour                 Black
# Odometer (KM)          11179
# Doors                      5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
animals.iloc[:3] #items upto position 3
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
#to select a column
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make   #give same result
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])  #different doors 3 4 5 and make
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#group by
car_sales.groupby(["Make"]).mean()
#gave mean values of the elements of make
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist() #histogram

# %%
car_sales["Price"].plot() #becase price is not numeric hence it will not plot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-167-9aeac0b85495> in <module>
# ----> 1 car_sales["Price"].plot() #becase price is not numeric hence it will not plot
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].plot()

# %%
car_sales["Price"] = car_sales["Price"]/100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Price"].plot()

# %% [markdown]
# ## Maniplating data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
#you need to assign it to change the actual df
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("/content/drive/MyDrive/Datas/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#the use of fillna function
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#to remove the row with missing values
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("/content/drive/MyDrive/Datas/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
#column from series
seats_column = pd.Series([5,5,5,5,5])

#new column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
#column from python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
#if you're importing from python list, it should be of the same length while pandas series can be of any length
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5

# %%
car_sales["Total fuel used (L"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         3473.048
# 7         4762.206
# ...

# %%
#create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# ...

# %%
car_sales["Passed road safety"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed road safety  Total fuel used (L
# 0        11253.225                 4                True           11253.225
# ...

# %%
car_sales.drop("Total fuel used", axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Number of wheels  Passed road safety  Total fuel used (L
# 0                 4                True           11253.225
# 1                 4                True            8086.708
# ...

# %%
#to randomize the data
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 9  nissan  White          31600      4   9700.0    5.0             4.5
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
#
#    Number of wheels  Passed road safety  Total fuel used (L
# 0                 4                True           11253.225
# 5                 4                True            4663.011
# ...

# %%
#only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4  4000.0    5.0             7.5
# 8  toyota  White          60000      4  6250.0    5.0             3.0
#
#    Number of wheels  Passed road safety  Total fuel used (L
# 0                 4                True           11253.225
# 8                 4                True            1800.000

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 9  nissan  White          31600      4   9700.0    5.0             4.5
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
#
#    Number of wheels  Passed road safety  Total fuel used (L
# 0                 4                True           11253.225
# 5                 4                True            4663.011
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1  toyota  Green          99213      4   4500.0    5.0             4.7
# 2     bmw  Black          11179      5  22000.0    5.0             9.6
# 3  toyota   Blue          32549      3   7000.0    5.0             5.0
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5   honda   Blue          54738      4   7000.0    5.0             8.7
# 6  toyota  White          60000      4   6250.0    5.0             3.0
# 7   honda    Red          87899      4   5000.0    5.0             9.2
# 8  nissan  White          31600      4   9700.0    5.0             4.5
# 9   honda   Blue          45698      4   7500.0    5.0             7.6
#
#    Number of wheels  Passed road safety  Total fuel used (L
# 0                 4                True           11253.225
# 1                 4                True            4663.011
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.7
# 6   honda   Blue          45698      4   7500.0    5.0             7.6
# 7   honda   Blue          54738      4   7000.0    5.0             8.7
# 8  toyota  White          60000      4   6250.0    5.0             3.0
# 9  nissan  White          31600      4   9700.0    5.0             4.5
#
#    Number of wheels  Passed road safety  Total fuel used (L
# 0                 4                True           11253.225
# 1                 4                True            8086.708
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White   58610.546875      4   4000.0    5.0             7.5
# 1   honda    Red   34335.546875      4   5000.0    5.0             9.2
# 2  toyota   Blue   12714.453125      3   7000.0    5.0             5.0
# 3     bmw  Black    4366.796875      5  22000.0    5.0             9.6
# 4  nissan  White   83240.234375      4   3500.0    5.0             8.7
# 5  toyota  Green   38755.078125      4   4500.0    5.0             4.7
# 6   honda   Blue   17850.781250      4   7500.0    5.0             7.6
# 7   honda   Blue   21382.031250      4   7000.0    5.0             8.7
# 8  toyota  White   23437.500000      4   6250.0    5.0             3.0
# 9  nissan  White   12343.750000      4   9700.0    5.0             4.5
#
#    Number of wheels  Passed road safety  Total fuel used (L
# 0                 4                True           11253.225
# 1                 4                True            8086.708
# ...
